# %% [markdown]
# <a href="https://colab.research.google.com/github/Daria13-gif/cs102/blob/homework06/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ЗАДАНИЕ 1
# 1. Загрузите датасет music_genre.csv.
# 2. Возьмите 20 тысяч случайных строк из датасета (все остальные задания выполняйте для этих 20 тысяч строк!!!)
# 3. Проверьте, есть ли в датасете дублирующиеся строки. Если есть, удалите их.
# 4. Проверьте, есть ли а датасете строки, в которых значение в столбце artist_name – empty_field. Если есть, выведите эти строки и их количество. А затем удалите из датасета.

# %%
# Загрузите датасет music_genre.csv
library(dplyr)
df <- read.csv('music_genre.csv')

# Возьмите 20 тысяч случайных строк из датасета
df <- sample_n(df, 20000)

# проверьте, есть ли в датасете дублирующиеся строки. Если есть, удалите их
df <- distinct(df)

# строки, в которых значение в столбце artist_name – empty_field - удалить
nrow(df[df$artist_name == 'empty_field', ])
new_df <- subset(df, artist_name!='empty_field')
new_df <- na.omit(new_df)
new_df
# Out:
# [1] 1021
#       instance_id artist_name
# 1     59534       Kyle Park
# 2     52461       Jóhann Jóhannsson
# 4     52346       Coheed and Cambria
# 5     41746       Andrea Bocelli
# 6     40579       Kip Moore
# 7     55464       Fear, and Loathing in Las Vegas
# 8     44277       Emapea
# 9     31035       Linkin Park
# 10    87166       Al Jarreau
# 11    28946       Leon Bridges
# 12    40677       Jamie Cullum
# 13    65548       Hot Chip
# 14    55179       Joni Mitchell
# 15    57582       Beth Hart
# 16    53185       The California Honeydrops
# 17    61810       The Heavy
# 18    21879       Sheryl Crow
# 19    47408       San Holo
# 20    47928       Nobuo Uematsu
# 21    57805       Austin Wintory
# 22    84630       The Weeknd
# 23    37716       Nightmares On Wax
# 24    66013       Papa Roach
# 25    63648       Duke Ellington
# 26    60892       Nobuo Uematsu
# 27    43168       The 1975
# 28    60782       Los Enanitos Verdes
# 29    68152       Adelitas Way
# 30    67927       Dave Edmunds
# 31    81972       Louis Prima
# ⋮     ⋮           ⋮
# 19968 62541       The Police
# 19970 60105       Leonard Bernstein
# 19972 39584       George Frideric Handel
# 19973 40490       Yung Gravy
# 19974 66289       Poppin'Party
# 19975 44104       Passion Pit
# 19976 36290       Yeah Yeah Yeahs
# 19977 50482       New Order
# 19978 21023       Apashe
# 19979 59306       Drake
# 19980 25669       Funkadelic
# 19982 29569       Rittz
# 19983 34499       Miranda Lambert
# 19984 36096       Ryuichi Sakamoto
# 19985 62075       JOYRYDE
# 19986 45398       Diddy
# 19987 84737       Tantric
# 19988 83174       Aimer
# 19989 71917       DRAMA
# 19990 62285       George Duke
# 19991 22187       Kanon Wakeshima
# 19992 30420       Kelsea Ballerini
# 19993 70232       Eptic
# 19994 54395       Ben Folds
# 19995 88678       Papa Roach
# 19996 48855       The Platters
# 19997 38515       Breakestra
# 19998 73929       Chris Webby
# 19999 76798       The Who
# 20000 42559       MAXIMUM THE HORMONE
#       track_name
# 1     Leavin' Stephenville
# 2     Convoy
# 4     Time Consumer
# 5     Un Amore Così Grande - Remastered
# 6     Lipstick
# 7     Step of Terror
# 8     The Winner
# 9     In the End
# 10    Your Song
# 11    Coming Home - Live at SXSW 2015
# 12    Show Me The Magic
# 13    Colours
# 14    All I Want
# 15    Bang Bang Boom Boom
# 16    Big Fat Woman
# 17    The Lonesome Road
# 18    Soak Up The Sun
# 19    Still Looking - CESQEAUX Remix
# 20    Continue
# 21    Timidly, into a Garden
# 22    Try Me
# 23    You Wish
# 24    Scars
# 25    Isfahan
# 26    Find Your Way: Piano Collections Version (From "Final Fantasy VIII") [For Piano Solo]
# 27    Sex
# 28    La Muralla Verde
# 29    Still Hungry
# 30    Girls Talk
# 31    That Old Black Magic - Remastered
# ⋮     ⋮
# 19968 Wrapped Around Your Finger - Remastered 2003
# 19970 West Side Story (Original Broadway Cast): Act I: Tonight
# 19972 Rinaldo, HWV 7a, Act II (Ed. G. Sechi): Qual incognita forza [Live]
# 19973 Alley Oop (feat. Lil Baby)
# 19974 What's the POPIPA!?
# 19975 I Found U
# 19976 Heads Will Roll - A-Trak Remix Radio Edit
# 19977 Restless
# 19978 Battle Royale - Haters Instrumental VIP
# 19979 Survival
# 19980 Maggot Brain
# 19982 I'm Only Human
# 19983 I've Got Wheels
# 19984 Arriving at Fort Kiowa
# 19985 MERCY
# 19986 I'll Be Missing You (feat. Faith Evans & 112)
# 19987 Down And Out
# 19988 Broken Night
# 19989 Walk Away
# 19990 No Rhyme, No Reason
# 19991 Sakurameikyu
# 19992 The First Time
# 19993 Watch Out
# 19994 The Luckiest
# 19995 Last Resort
# 19996 You'll Never Never Know
# 19997 Hiding
# 19998 HipHop Legend (feat. JAG & Jon Connor)
# 19999 Tommy's Holiday Camp - Remixed Album Version
# 20000 Koino Kinako Watashini Kudasai
#       popularity acousticness danceability duration_ms energy instrumentalness
# 1     42         1.32e-01     0.5270       208440      0.8230 0.00e+00
# 2     32         7.11e-01     0.5070           -1      0.1530 8.82e-01
# 4     41         4.37e-04     0.2940       341693      0.9590 5.32e-05
# 5     36         9.32e-01     0.3050       262387      0.4710 2.28e-03
# 6     43         3.43e-03     0.4590       257853      0.7780 1.12e-05
# 7     20         1.54e-04     0.4160       209133      0.9890 3.04e-02
# 8     39         3.02e-02     0.9260       139611      0.5150 8.76e-01
# 9     80         1.03e-02     0.5420       216933      0.8530 0.00e+00
# 10    44         6.89e-01     0.5230       338387      0.3040 2.42e-02
# 11    31         5.42e-01     0.4080       228133      0.5430 0.00e+00
# 12    51         2.60e-01     0.6010       150413      0.4930 0.00e+00
# 13    39         9.83e-02     0.7460       328947      0.5810 1.09e-03
# 14    55         7.25e-01     0.6780       214240      0.4440 0.00e+00
# 15    32         5.60e-02     0.6990       217987      0.7140 4.21e-03
# 16    28         3.23e-01     0.6560       171880      0.7740 5.57e-05
# 17    28         1.25e-01     0.7530       236120      0.4920 0.00e+00
# 18    55         4.18e-02     0.7150       292307      0.7500 0.00e+00
# 19    40         1.32e-01     0.6170       189200      0.8040 4.59e-05
# 20    28         9.35e-01     0.2940        37027      0.3490 5.81e-01
# 21    15         9.36e-01     0.0986       336542      0.0639 8.71e-01
# 22    74         6.22e-01     0.4660           -1      0.6720 1.08e-03
# 23    62         7.20e-01     0.7740           -1      0.2440 9.15e-01
# 24    60         9.48e-02     0.3840       208186      0.9210 0.00e+00
# 25    39         9.75e-01     0.2470       245880      0.0720 6.31e-01
# 26    14         9.89e-01     0.3750       215061      0.0498 8.45e-01
# 27    54         1.35e-05     0.4030       206987      0.9710 2.22e-05
# 28    69         6.53e-02     0.7240       161800      0.8560 1.85e-06
# 29    48         1.24e-02     0.4880       191781      0.9690 0.00e+00
# 30    37         5.29e-02     0.5600       206453      0.8450 8.97e-04
# 31    35         2.51e-01     0.6370       177493      0.3970 4.85e-06
# ⋮     ⋮          ⋮            ⋮            ⋮           ⋮      ⋮
# 19968 50         0.089700     0.742        313707      0.4440 3.29e-04
# 19970 26         0.919000     0.252        232933      0.1200 2.40e-06
# 19972  6         0.984000     0.614         54997      0.1280 0.00e+00
# 19973 74         0.276000     0.861        152187      0.4990 0.00e+00
# 19974 30         0.001640     0.467        278333      0.9850 2.76e-05
# 19975 61         0.071300     0.530        207343      0.7310 2.59e-06
# 19976 55         0.017200     0.705        203920      0.8070 3.92e-02
# 19977 33         0.005950     0.512        328240      0.9630 5.07e-02
# 19978 35         0.014900     0.737        216000      0.8190 4.35e-01
# 19979 70         0.133000     0.607        136187      0.5960 0.00e+00
# 19980 56         0.777000     0.300        621107      0.3530 4.78e-01
# 19982 49         0.214000     0.758        299212      0.6850 2.13e-04
# 19983 40         0.113000     0.408        220560      0.7310 3.40e-03
# 19984 25         0.969000     0.147         81876      0.0344 9.07e-01
# 19985 36         0.004160     0.694        195402      0.9590 5.25e-03
# 19986 68         0.111000     0.833        306560      0.6190 2.13e-05
# 19987 49         0.196000     0.562        219693      0.8620 0.00e+00
# 19988 39         0.356000     0.309        296307      0.6880 0.00e+00
# 19989 49         0.150000     0.827        258599      0.4770 2.14e-01
# 19990 38         0.381000     0.629        346600      0.5460 3.40e-03
# 19991 29         0.043300     0.268        276160      0.8390 0.00e+00
# 19992 42         0.715000     0.611        212337      0.6200 0.00e+00
# 19993 35         0.101000     0.657        225103      0.9880 4.58e-01
# 19994 50         0.890000     0.374            -1      0.1850 7.46e-04
# 19995 78         0.000481     0.589        199907      0.8900 8.20e-04
# 19996 42         0.915000     0.407        160840      0.3790 0.00e+00
# 19997 50         0.242000     0.681            -1      0.8570 6.59e-04
# 19998 55         0.077200     0.763        254576      0.6210 0.00e+00
# 19999 23         0.927000     0.752            -1      0.3320 6.03e-01
# 20000 19         0.806000     0.546         67000      0.4160 4.29e-04
#       key liveness loudness mode  speechiness tempo              obtained_date
# 1     G   0.2160    -3.892  Major 0.0349      97.978             4-Apr
# 2     B   0.1180   -24.823  Minor 0.0384      90.09299999999999  4-Apr
# 4     D   0.0858    -2.794  Minor 0.0627      ?                  4-Apr
# 5     E   0.1370    -6.348  Major 0.0351      ?                  3-Apr
# 6     E   0.1220    -5.105  Major 0.0329      144.036            4-Apr
# 7     G   0.2260    -0.911  Major 0.1260      100.12899999999999 4-Apr
# 8     E   0.1650    -7.209  Minor 0.0647      ?                  4-Apr
# 9     D#  0.1080    -6.407  Minor 0.0498      105.256            4-Apr
# 10    D#  0.1060   -12.081  Major 0.0333      120.39200000000001 4-Apr
# 11    F#  0.7200    -7.079  Major 0.0656      ?                  3-Apr
# 12    F   0.2490    -5.336  Minor 0.0425      ?                  4-Apr
# 13    C   0.0807    -7.247  Major 0.0575      ?                  4-Apr
# 14    F#  0.1210   -10.518  Major 0.0326      141.262            4-Apr
# 15    C   0.1030    -8.874  Major 0.0284      104.075            4-Apr
# 16    A#  0.1230    -6.176  Minor 0.1430      101.132            4-Apr
# 17    C   0.1520    -8.438  Major 0.0426      85.98              4-Apr
# 18    E   0.1390    -4.898  Major 0.0448      119.992            4-Apr
# 19    F#  0.0901    -6.015  Major 0.0860      150.055            4-Apr
# 20    C   0.1580   -17.519  Major 0.0475      155.418            4-Apr
# 21    G   0.1230   -23.251  Major 0.0368      ?                  3-Apr
# 22    G#  0.1470    -5.777  Minor 0.0680      91.67299999999999  4-Apr
# 23    A   0.3790    -9.748  Minor 0.0299      103.464            4-Apr
# 24    B   0.1680    -3.334  Major 0.0550      89.92200000000001  4-Apr
# 25    G#  0.1010   -13.544  Major 0.0320      173.372            3-Apr
# 26    G   0.1180   -27.067  Major 0.0554      76.492             4-Apr
# 27    D   0.4880    -4.159  Major 0.1120      148.32399999999998 4-Apr
# 28    G#  0.3540    -6.119  Minor 0.0283      129.79399999999998 4-Apr
# 29    E   0.0805    -3.133  Minor 0.1160      93.014             4-Apr
# 30    C#  0.0479    -7.097  Major 0.0344      129.115            4-Apr
# 31    D   0.2550   -12.149  Minor 0.1340      124.206            4-Apr
# ⋮     ⋮   ⋮        ⋮        ⋮     ⋮           ⋮                  ⋮
# 19968 A   0.0577   -11.470  Minor 0.0351      127.663            4-Apr
# 19970 C   0.2160   -19.058  Minor 0.0380      137.429            5-Apr
# 19972 A#  0.3280   -15.931  Minor 0.3470      102.93700000000001 4-Apr
# 19973 F#  0.0971    -7.458  Major 0.2630      122.00299999999999 4-Apr
# 19974 D   0.3300    -1.845  Major 0.1040      186.063            4-Apr
# 19975 G#  0.1090    -5.299  Major 0.0453      123.943            4-Apr
# 19976 G#  0.2320    -3.157  Minor 0.0845      132.025            4-Apr
# 19977 B   0.0646    -5.083  Minor 0.0498      143.012            4-Apr
# 19978 G   0.0704    -5.841  Major 0.0878      100.025            4-Apr
# 19979 A   0.1230    -9.090  Minor 0.3580      77.324             4-Apr
# 19980 E   0.4060   -15.588  Minor 0.0470      134.912            3-Apr
# 19982 C#  0.0739    -5.818  Minor 0.0446      116.991            4-Apr
# 19983 C   0.1380    -7.171  Major 0.0359      153.813            4-Apr
# 19984 E   0.1610   -23.023  Minor 0.0555      175.31799999999998 4-Apr
# 19985 B   0.1720    -1.893  Major 0.3480      135.046            4-Apr
# 19986 G   0.1590    -5.595  Major 0.0538      109.92             4-Apr
# 19987 C#  0.0962    -4.928  Minor 0.0439      86.99799999999999  4-Apr
# 19988 F   0.1410    -5.690  Major 0.0525      169.963            4-Apr
# 19989 F#  0.1120    -6.861  Minor 0.0456      118.96600000000001 4-Apr
# 19990 D   0.1160   -11.656  Minor 0.0273      127.525            4-Apr
# 19991 C   0.1290    -3.181  Major 0.0497      170.014            4-Apr
# 19992 A#  0.1140    -6.103  Major 0.1130      ?                  4-Apr
# 19993 C#  0.1160    -4.315  Major 0.0818      145.005            4-Apr
# 19994 D   0.1050   -11.846  Major 0.0366      120.51899999999999 4-Apr
# 19995 E   0.2010    -3.719  Minor 0.0603      90.598             4-Apr
# 19996 C#  0.1060   -10.944  Major 0.0331      99.943             4-Apr
# 19997 D   0.0725    -4.187  Major 0.0325      102.63600000000001 4-Apr
# 19998 C#  0.0791    -7.662  Major 0.4250      144.836            4-Apr
# 19999 B   0.1070   -16.116  Major 0.0896      136.33700000000002 4-Apr
# 20000 C#  0.1670    -7.175  Major 0.0342      123.325            4-Apr
#       valence music_genre
# 1     0.6340  Country
# 2     0.0348  Classical
# 4     0.4810  Alternative
# 5     0.1670  Classical
# 6     0.6220  Country
# 7     0.1560  Anime
# 8     0.8960  Jazz
# 9     0.3700  Alternative
# 10    0.1140  Jazz
# 11    0.6340  Blues
# 12    0.5780  Jazz
# 13    0.4240  Electronic
# 14    0.7860  Rock
# 15    0.8170  Blues
# 16    0.8840  Blues
# 17    0.6830  Blues
# 18    0.7100  Rock
# 19    0.6420  Electronic
# 20    0.0298  Anime
# 21    0.0384  Anime
# 22    0.1080  Rap
# 23    0.4210  Jazz
# 24    0.4710  Alternative
# 25    0.0872  Jazz
# 26    0.1500  Anime
# 27    0.1840  Alternative
# 28    0.8910  Alternative
# 29    0.2960  Alternative
# 30    0.8840  Blues
# 31    0.7130  Jazz
# ⋮     ⋮       ⋮
# 19968 0.5880  Rock
# 19970 0.1470  Classical
# 19972 0.3840  Classical
# 19973 0.8610  Rap
# 19974 0.6320  Anime
# 19975 0.3850  Alternative
# 19976 0.8800  Rock
# 19977 0.7010  Electronic
# 19978 0.5000  Electronic
# 19979 0.1490  Hip-Hop
# 19980 0.1900  Jazz
# 19982 0.0650  Hip-Hop
# 19983 0.3260  Country
# 19984 0.0326  Anime
# 19985 0.3060  Electronic
# 19986 0.9010  Hip-Hop
# 19987 0.6920  Alternative
# 19988 0.4850  Anime
# 19989 0.2900  Alternative
# 19990 0.2810  Jazz
# 19991 0.4770  Anime
# 19992 0.6780  Jazz
# 19993 0.4310  Electronic
# 19994 0.2260  Rock
# 19995 0.6920  Rap
# 19996 0.6450  Blues
# 19997 0.8670  Jazz
# 19998 0.6920  Rap
# 19999 0.7920  Blues
# 20000 0.2130  Anime

# %% [markdown]
# ЗАДАНИЕ 2
# 1. Выведите долю каждого жанра в датасете.
# 2. Покажите на горизонтальной столбиковой диаграмме распределение количества треков по жанрам. Выделите контрастным цветом жанр, в котором больше всего песен.
# 3. Найдите самый танцевальный жанр. У самого танцевального жанра среднее значение показателя danceability должно быть наивысшим.
# 4. Для каждого жанра определите, какая тональность в нем преобладает – количество треков какой тональность больше (минор или мажор).

# %%
# 1. Выведите долю каждого жанра в датасете
new_df <- na.omit(new_df)
genre_props <- prop.table(table(df$music_genre))

cat("Доля каждого жанра в датасете:\n")
print(genre_props)
# Out:
# Доля каждого жанра в датасете:
#
#             Alternative       Anime       Blues   Classical     Country
#     0.00005     0.09840     0.10345     0.10215     0.09845     0.09955
#  Electronic     Hip-Hop        Jazz         Rap        Rock
#     0.09840     0.09915     0.10005     0.09970     0.10065

# %%
# 2. Покажите на горизонтальной столбиковой диаграмме распределение количества треков по жанрам   
library(ggplot2) 

new_df <- na.omit(new_df)
genre_count <- new_df %>%
  count(music_genre) %>%
  mutate(share = n / sum(n)) %>%
  arrange(desc(share))
genre_count

barplot(genre_count$share, names.arg = genre_count$music_genre, las = 2, 
horiz = TRUE)
# Out:
#    music_genre n    share
# 1  Blues       1759 0.10283543
# 2  Anime       1751 0.10236773
# 3  Jazz        1720 0.10055539
# 4  Rock        1713 0.10014616
# 5  Country     1705 0.09967846
# 6  Electronic  1704 0.09961999
# 7  Hip-Hop     1695 0.09909383
# 8  Alternative 1693 0.09897691
# 9  Rap         1689 0.09874306
# 10 Classical   1676 0.09798305
# plot without title

# %%
# 3. Найдите самый танцевальный жанр
danceability_by_genre <- new_df %>% 
  group_by(music_genre) %>% 
  summarize(mean_danceability = mean(danceability))

most_danceable_genre <- danceability_by_genre %>% 
  arrange(desc(mean_danceability)) %>% 
  head(1)

cat("Самый танцевальный жанр:", most_danceable_genre$music_genre, "\n")
cat("Среднее значение показателя danceability:", most_danceable_genre$mean_danceability, "\n")
# Out:
# Самый танцевальный жанр: Hip-Hop
# Среднее значение показателя danceability: 0.7167508

# %%
# 4. Для каждого жанра определите, какая тональность в нем преобладает – количество треков какой тональность больше
library(ggplot2)

new_df <- na.omit(new_df)
tonality_by_genre <- new_df %>%
  group_by(music_genre, key) %>%
  summarise(track_count = n()) %>%
  mutate(mode = ifelse(sum(key == "C") == 0 & sum(key == "D") == 0, "No tracks",
                       ifelse(track_count[key == "C"] < track_count[key == "D"], "major", "minor")))
ggplot(tonality_by_genre, aes(x = music_genre, y = track_count, fill = mode)) +
  geom_bar(stat = "identity") +
  labs(title = "Преобладающая тональность по жанрам", 
       x = "Жанры", y = "Количество треков") +
  scale_fill_manual(values = c("#377eb8", "#e41a1c", "#999999"), 
                    labels = c("мажор", "минор")) +
  theme(axis.text.x = element_text(angle = 45, vjust = 0.5))
# Out:
# `summarise()` has grouped output by 'music_genre'. You can override using the
# `.groups` argument.
# plot without title

# %% [markdown]
# ЗАДАНИЕ 3
# 1. Выведите исполнителя, у которого больше всего треков в датасете. И того, у которого их меньше всех.
# 2. Покажите на горизонтральной столбиковой диаграмме топ-20 исполнителей. Изучите результат и сделайте выводы.

# %%
# 1. Выведите исполнителя, у которого больше всего треков в датасете
new_df <- na.omit(new_df)
most_tracks <- names(sort(table(new_df$artist_name), decreasing = TRUE)[1])
most_count <- max(table(new_df$artist_name))
cat("Исполнитель с наибольшим количеством треков:", most_tracks, "(", most_count, "треков)\n")

least_tracks <- names(sort(table(new_df$artist_name))[1])
least_count <- min(table(new_df$artist_name))
cat("Исполнитель с наименьшим количеством треков:", least_tracks, "(", least_count, "трек)\n")
# Out:
# Исполнитель с наибольшим количеством треков: Nobuo Uematsu ( 169 треков)
# Исполнитель с наименьшим количеством треков: "Weird Al" Yankovic ( 1 трек)

# %%
# 2. Покажите на горизонтральной столбиковой диаграмме топ-20 исполнителей
library(ggplot2)

top_artists <- new_df %>%
  group_by(artist_name) %>%
  summarize(total_songs = n()) %>%
  top_n(20, total_songs) %>%
  arrange(desc(total_songs))

ggplot(top_artists, aes(y = reorder(artist_name, -total_songs), x = total_songs)) +
  geom_bar(stat = "identity", fill = "steelblue") +
  theme(axis.text.y = element_text(hjust = 1)) +
  ggtitle("Топ-20 исполнителей по количеству треков") +
  xlab("Количество треков") +
  ylab("Исполнитель")
# Out:
# plot without title

# %% [markdown]
# ЗАДАНИЕ 4
# 1. Постройте корреляционную матрицу для характеристик треков. Между какими характеристиками сильная корреляция? Между какими слабая? Есть ли характеристики, между которыми корреляции практически нет.
# 2. Посчитайте корреляцию между популярностью (popularity) и длиной названия трека.

# %%
# 1. Постройте корреляционную матрицу для характеристик треков
new_df <- na.omit(new_df)
install.packages("corrplot")
library(corrplot)

cor_df <- select_if(new_df, is.numeric)
head(cor_df)
# кореляционная матрица
M<-cor(cor_df, use="pairwise.complete.obs")
head(round(M,3))
corrplot(M, method="color")
corrplot(M, method="number")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#   instance_id popularity acousticness danceability duration_ms energy
# 1 59534       42         0.132000     0.527        208440      0.823
# 2 52461       32         0.711000     0.507            -1      0.153
# 4 52346       41         0.000437     0.294        341693      0.959
# 5 41746       36         0.932000     0.305        262387      0.471
# 6 40579       43         0.003430     0.459        257853      0.778
# 7 55464       20         0.000154     0.416        209133      0.989
#   instrumentalness liveness loudness speechiness valence
# 1 0.00e+00         0.2160    -3.892  0.0349      0.6340
# 2 8.82e-01         0.1180   -24.823  0.0384      0.0348
# 4 5.32e-05         0.0858    -2.794  0.0627      0.4810
# 5 2.28e-03         0.1370    -6.348  0.0351      0.1670
# 6 1.12e-05         0.1220    -5.105  0.0329      0.6220
# 7 3.04e-02         0.2260    -0.911  0.1260      0.1560
#              instance_id popularity acousticness danceability duration_ms
# instance_id   1.000       0.006     -0.009        0.004       -0.013
# popularity    0.006       1.000     -0.276        0.356       -0.085
# acousticness -0.009      -0.276      1.000       -0.342        0.056
# danceability  0.004       0.356     -0.342        1.000       -0.147
# duration_ms  -0.013      -0.085      0.056       -0.147        1.000
# energy        0.014       0.203     -0.792        0.260       -0.060
#              energy instrumentalness liveness loudness speechiness valence
# instance_id   0.014  0.000           -0.007    0.005   -0.011       0.006
# popularity    0.203 -0.362           -0.038    0.305    0.222       0.117
# acousticness -0.792  0.385           -0.110   -0.728   -0.161      -0.273
# danceability  0.260 -0.291           -0.059    0.384    0.288       0.432
# duration_ms  -0.060  0.124            0.018   -0.095   -0.086      -0.128
# energy        1.000 -0.387            0.187    0.841    0.149       0.393
# Plot with title “”
# Plot with title “”

# %%
# 2. Посчитайте корреляцию между популярностью (popularity) и длиной названия трека
cor_df <- select_if(new_df, is.numeric)
cat(cor(new_df$popularity, new_df$duration_ms, use = "complete.obs"))
# Out:
# -0.08517836

# %% [markdown]
# ЗАДАНИЕ 5
# 1. Покажите на ящиковой диаграмме отношение популярности треков к жанру. Какие жанры похожи между собой?

# %%
# 1. Покажите на ящиковой диаграмме отношение популярности треков к жанру
par(mar=c(6,4,4,0))
boxplot(popularity ~ music_genre, data = new_df,
        las=2,
        xlab = "music genre",
        ylab = "popularity",
        main = "the ratio of the popularity of tracks to the genre",
        col = "pink",
        cex.lab=0.7)
# Out:
# Plot with title “the ratio of the popularity of tracks to the genre”

# %% [markdown]
# ЗАДАНИЕ 7
# 1. На вертикальной столбиковой диаграмме для самого популярного (popularity) и самого непопулярного жанров покажите средние значения по всем характеристикам. Отрицательные и положительные значения характеристик показывайте разными цветами.

# %%
new_df <- na.omit(new_df)
df <- new_df
grouped <- df %>% group_by(music_genre)  %>%
                      summarise(status = mean(popularity))  # складываем тот же датасет, сгруппированный по жанрам и средним значениям популярности

most_popular <- (grouped %>% filter(max(status) == status))[[1]]
least_popular <- (grouped %>% filter(min(status) == status))[[1]]  #Находим по табличке самый популярный и самый непопулярный жанр с помощью фильтрации и извлекаем строки с этими жанрами из датасета
ee <- subset(df, music_genre == most_popular)
yy <- subset(df, music_genre == least_popular)

ee <- ee[,!names(ee) %in% c("instance_id", "popularity", "duration_ms")]
yy <- yy[,!names(yy) %in% c("instance_id", "popularity", "duration_ms")]

ee <- ee[ , unlist(lapply(ee, is.numeric))]    # Identify numeric columns
yy <- yy[ , unlist(lapply(yy, is.numeric))] 

X <- as.numeric(unlist(colMeans(ee)))  # Извлекаем для таблицы самого популярного жанра средние значения по каждому столбцу и названия столбцов
Y <- names(unlist(colMeans(ee)))

colors = list()
for(i in 1:length(X)) {                                    
  if (X[i] < 0) {
    colors[[length(colors) + 1]] <- 'red'
  } else {
    colors[[length(colors) + 1]] <- 'yellow'
  }                           
}
v = unlist(c(colors))

par(mar=c(4,7,4,3))
barplot(X,names.arg=c(Y),
ylab="Характеристики",
col=v, 
main=most_popular, 
beside = TRUE, 
cex.names=0.5, 
ylim = c(-8, 2), 
las=1)

X <- as.numeric(unlist(colMeans(yy)))
Y <- names(unlist(colMeans(yy)))

colors = list()
for(i in 1:length(X)) {                                    
  if (X[i] < 0) {
    colors[[length(colors) + 1]] <- 'red'
  } else {
    colors[[length(colors) + 1]] <- 'yellow'
  }                           
}
v = unlist(c(colors))

par(mar=c(4,7,4,1))
barplot(X,names.arg=c(Y),
ylab="Характеристики",
col=v, 
main=least_popular, 
beside = TRUE, 
cex.names=0.5, 
ylim = c(-8, 2), 
las=1)
# Out:
# Plot with title “Rap”
# Plot with title “Anime”

# %% [markdown]
# ЗАДАНИЕ 8
# 1. Добавьте в данные категориальный столбец длительность_трека, в котором будут значения: "короткая" (<=3min), "средняя" (>3min, <=5min), "длинная" (>5min).
# 2. Покажите график плотности распределения данных в столбце loudness, сгруппированных по категориям длительности.
# 3. На круговой диаграмме покажите численное соотношение треков разной длительности.

# %%
# 1. Добавьте в данные категориальный столбец длительность_трека, в котором будут значения: "короткая", "средняя", "длинная"
library(ggplot2)
new_df$длительность_трека <- cut(new_df$duration_ms/1000/60, 
                                      breaks = c(0, 3, 5, Inf), 
                                      labels = c("короткая", "средняя", "длинная"))
new_df <- subset(new_df, длительность_трека!='NA')
#new_df$длительность_трека

# %%
# 2. Покажите график плотности распределения данных в столбце loudness, сгруппированных по категориям длительности
#head(new_df)
ggplot(new_df, aes(x = loudness, fill = длительность_трека)) + 
  geom_density(alpha = 0.5) +
  xlab("Loudness") +
  ylab("Density") +
  ggtitle("Плотность распределения громкости по длительности трека")
# Out:
# plot without title

# %%
# 3. На круговой диаграмме покажите численное соотношение треков разной длительности
#head(new_df)
ggplot(new_df, aes(x = "", fill = длительность_трека)) + 
  geom_bar(width = 1) +
  coord_polar("y", start=0) +
  labs(fill = "Длительность") +
  ggtitle("Численное соотношение треков разной длительности")
# Out:
# plot without title
